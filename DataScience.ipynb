# %% [markdown]
# <a href="https://colab.research.google.com/github/SNIGDHA-ms24043/IDC-PROJECT--Music-Genre-Classification/blob/main/DataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello Gurleen")
# Out:
# hello Gurleen
